# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import glob
import cv2

# %%
all_image = []
all_label = []
def vol_(path):
    for index,folder in enumerate(os.listdir(path)):
        print(index,folder)
        image = []
        for row in os.listdir(path+'\\'+folder):
            pat_path = path+'\\'+folder+'\\'+row
            all_image.append(pat_path)
            all_label.append(index)
    return 0

# %%
image_train_set = vol_(r'C:\Users\AIIMS-IITD\Desktop\Sanjeev\4_class_cluster_volume\Train')
# Out:
# 0 00_5
# 1 06_10
# 2 11_16
# 3 17_28

# %%
len(all_image)
# Out:
# 116

# %%
volume_list = []
for item in all_image:
    count = 0
    item_list = []
    for files in os.listdir(item):
        path = item+'\\'+files
        item_list.append(path)
    volume_list.append(item_list)

# %%
bin_container = []
for volume in volume_list:
    total_samples = len(volume)
    bin_vol = []
    for i in range(25):
        bin_ = []
        for i in range(0,total_samples-10):
            #r = random.randint(0,6)
            bin_.append([volume[i+6]])
        bin_vol.append(bin_)
    bin_container.append(bin_vol)

# %%
len(volume_list[0])
# Out:
# 150

# %%
len(bin_container[0][0])
# Out:
# 140

# %%
volume_list[1]
# Out:
# ['C:\\Users\\AIIMS-IITD\\Desktop\\Sanjeev\\4_class_cluster_volume\\Train\\00_5\\171969\\IMG-0002-00036.jpg',
#  'C:\\Users\\AIIMS-IITD\\Desktop\\Sanjeev\\4_class_cluster_volume\\Train\\00_5\\171969\\IMG-0002-00037.jpg',
#  'C:\\Users\\AIIMS-IITD\\Desktop\\Sanjeev\\4_class_cluster_volume\\Train\\00_5\\171969\\IMG-0002-00038.jpg',
#  'C:\\Users\\AIIMS-IITD\\Desktop\\Sanjeev\\4_class_cluster_volume\\Train\\00_5\\171969\\IMG-0002-00039.jpg',
#  'C:\\Users\\AIIMS-IITD\\Desktop\\Sanjeev\\4_class_cluster_volume\\Train\\00_5\\171969\\IMG-0002-00040.jpg',
#  'C:\\Users\\AIIMS-IITD\\Desktop\\Sanjeev\\4_class_cluster_volume\\Train\\00_5\\171969\\IMG-0002-00041.jpg',
#  'C:\\Users\\AIIMS-IITD\\Desktop\\Sanjeev\\4_class_cluster_volume\\Train\\00_5\\171969\\IMG-0002-00042.jpg',
#  'C:\\Users\\AIIMS-IITD\\Desktop\\Sanjeev\\4_class_cluster_volume\\Train\\00_5\\171969\\IMG-0002-00043.jpg',
#  'C:\\Users\\AIIMS-IITD\\Desktop\\Sanjeev\\4_class_cluster_volume\\Train\\00_5\\171969\\IMG-0002-00044.jpg',
# ...

# %%
bin_contain = []
for item in volume_list:
    total_samples = len(item)
    lst = []
    count = 0
    for i in range(10,total_samples-10,1):
        print(item[i-10:i+10])
        count += 1
    print(count)
    break
# Out:
# ['C:\\Users\\AIIMS-IITD\\Desktop\\Sanjeev\\4_class_cluster_volume\\Train\\00_5\\161885\\IMG-0029-00031.jpg', 'C:\\Users\\AIIMS-IITD\\Desktop\\Sanjeev\\4_class_cluster_volume\\Train\\00_5\\161885\\IMG-0029-00032.jpg', 'C:\\Users\\AIIMS-IITD\\Desktop\\Sanjeev\\4_class_cluster_volume\\Train\\00_5\\161885\\IMG-0029-00033.jpg', 'C:\\Users\\AIIMS-IITD\\Desktop\\Sanjeev\\4_class_cluster_volume\\Train\\00_5\\161885\\IMG-0029-00034.jpg', 'C:\\Users\\AIIMS-IITD\\Desktop\\Sanjeev\\4_class_cluster_volume\\Train\\00_5\\161885\\IMG-0029-00035.jpg', 'C:\\Users\\AIIMS-IITD\\Desktop\\Sanjeev\\4_class_cluster_volume\\Train\\00_5\\161885\\IMG-0029-00036.jpg', 'C:\\Users\\AIIMS-IITD\\Desktop\\Sanjeev\\4_class_cluster_volume\\Train\\00_5\\161885\\IMG-0029-00037.jpg', 'C:\\Users\\AIIMS-IITD\\Desktop\\Sanjeev\\4_class_cluster_volume\\Train\\00_5\\161885\\IMG-0029-00038.jpg', 'C:\\Users\\AIIMS-IITD\\Desktop\\Sanjeev\\4_class_cluster_volume\\Train\\00_5\\161885\\IMG-0029-00039.jpg', 'C:\\Users\\AIIMS-IITD\\D
# ...
