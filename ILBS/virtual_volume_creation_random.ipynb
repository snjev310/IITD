# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import glob
import cv2

# %%
all_image = []
all_label = []
def vol_(path):
    for index,folder in enumerate(os.listdir(path)):
        print(index,folder)
        image = []
        for row in os.listdir(path+'\\'+folder):
            pat_path = path+'\\'+folder+'\\'+row
            all_image.append(pat_path)
            all_label.append(index)
    return 0

# %%
image_train_set = vol_(r'C:\Users\AIIMS-IITD\Desktop\Sanjeev\4_class_cluster_volume\Train')
# Out:
# 0 00_5
# 1 06_10
# 2 11_16
# 3 17_28

# %%
len(all_image)
# Out:
# 116

# %%
for files in os.listdir(all_image[0]):
    print(files)
    break
# Out:
# IMG-0029-00031.jpg

# %%
volume_list = []
for item in all_image:
    count = 0
    item_list = []
    for files in os.listdir(item):
        path = item+'\\'+files
        item_list.append(path)
    volume_list.append(item_list)
#         count += 1
#     print(count)
#        print(path)

# %%
(volume_list)
# Out:
# [['C:\\Users\\AIIMS-IITD\\Desktop\\Sanjeev\\4_class_cluster_volume\\Train\\00_5\\161885\\IMG-0029-00031.jpg',
#   'C:\\Users\\AIIMS-IITD\\Desktop\\Sanjeev\\4_class_cluster_volume\\Train\\00_5\\161885\\IMG-0029-00032.jpg',
#   'C:\\Users\\AIIMS-IITD\\Desktop\\Sanjeev\\4_class_cluster_volume\\Train\\00_5\\161885\\IMG-0029-00033.jpg',
#   'C:\\Users\\AIIMS-IITD\\Desktop\\Sanjeev\\4_class_cluster_volume\\Train\\00_5\\161885\\IMG-0029-00034.jpg',
#   'C:\\Users\\AIIMS-IITD\\Desktop\\Sanjeev\\4_class_cluster_volume\\Train\\00_5\\161885\\IMG-0029-00035.jpg',
#   'C:\\Users\\AIIMS-IITD\\Desktop\\Sanjeev\\4_class_cluster_volume\\Train\\00_5\\161885\\IMG-0029-00036.jpg',
#   'C:\\Users\\AIIMS-IITD\\Desktop\\Sanjeev\\4_class_cluster_volume\\Train\\00_5\\161885\\IMG-0029-00037.jpg',
#   'C:\\Users\\AIIMS-IITD\\Desktop\\Sanjeev\\4_class_cluster_volume\\Train\\00_5\\161885\\IMG-0029-00038.jpg',
# ...

# %%
bin_container = []
for volume in volume_list:
    total_samples = len(volume)
    bin_vol = []
    for i in range(25):
        bin_ = []
        for i in range(0,total_samples-7,7):
            r = random.randint(0,6)
            bin_.append([volume[i+r]])
        bin_vol.append(bin_)
    bin_container.append(bin_vol)

# %%
len(bin_container[0][0])
# Out:
# 21

# %%
import random
r = random.randint(0,7)
print(r)
# Out:
# 2

# %%
len(bin_container[0])
# Out:
# 25

# %%
with open("file.txt", 'w') as output:
    for row in bin_container:
        if '00_5' in row:
            output.write(str(row) + '\n')
# Out:
# ['C:\\Users\\AIIMS-IITD\\Desktop\\Sanjeev\\4_class_cluster_volume\\Train\\00_5\\161885\\IMG-0029-00031.jpg']
# ['C:\\Users\\AIIMS-IITD\\Desktop\\Sanjeev\\4_class_cluster_volume\\Train\\00_5\\171969\\IMG-0002-00041.jpg']
# ['C:\\Users\\AIIMS-IITD\\Desktop\\Sanjeev\\4_class_cluster_volume\\Train\\00_5\\187107\\IMG-0041-00048.jpg']
# ['C:\\Users\\AIIMS-IITD\\Desktop\\Sanjeev\\4_class_cluster_volume\\Train\\00_5\\Study_84977\\imgdf00000208.jpg']
# ['C:\\Users\\AIIMS-IITD\\Desktop\\Sanjeev\\4_class_cluster_volume\\Train\\00_5\\Study_86151\\imgdf000001C2.jpg']
# ['C:\\Users\\AIIMS-IITD\\Desktop\\Sanjeev\\4_class_cluster_volume\\Train\\00_5\\Study_86905\\imgdf00000362.jpg']
# ['C:\\Users\\AIIMS-IITD\\Desktop\\Sanjeev\\4_class_cluster_volume\\Train\\00_5\\Study_87594\\imgdf000002E8.jpg']
# ['C:\\Users\\AIIMS-IITD\\Desktop\\Sanjeev\\4_class_cluster_volume\\Train\\00_5\\Study_88854\\imgdf000000FB.jpg']
# ...

# %%
len(bin_container)
# Out:
# 116

# %%
df = pd.DataFrame(bin_container)

# %%
df.head()
# Out:
#                                                   0   \
# 0  [[C:\Users\AIIMS-IITD\Desktop\Sanjeev\4_class_...
# 1  [[C:\Users\AIIMS-IITD\Desktop\Sanjeev\4_class_...
# 2  [[C:\Users\AIIMS-IITD\Desktop\Sanjeev\4_class_...
# 3  [[C:\Users\AIIMS-IITD\Desktop\Sanjeev\4_class_...
# 4  [[C:\Users\AIIMS-IITD\Desktop\Sanjeev\4_class_...
#
#                                                   1   \
# 0  [[C:\Users\AIIMS-IITD\Desktop\Sanjeev\4_class_...
# 1  [[C:\Users\AIIMS-IITD\Desktop\Sanjeev\4_class_...
# 2  [[C:\Users\AIIMS-IITD\Desktop\Sanjeev\4_class_...
# 3  [[C:\Users\AIIMS-IITD\Desktop\Sanjeev\4_class_...
# 4  [[C:\Users\AIIMS-IITD\Desktop\Sanjeev\4_class_...
#
#                                                   2   \
# 0  [[C:\Users\AIIMS-IITD\Desktop\Sanjeev\4_class_...
# 1  [[C:\Users\AIIMS-IITD\Desktop\Sanjeev\4_class_...
# 2  [[C:\Users\AIIMS-IITD\Desktop\Sanjeev\4_class_...
# 3  [[C:\Users\AIIMS-IITD\Desktop\Sanjeev\4_class_...
# ...

# %%
df.to_excel('result.xlsx', index = False)

# %%
[['C:\\Users\\AIIMS-IITD\\Desktop\\Sanjeev\\4_class_cluster_volume\\Train\\00_5\\161885\\IMG-0029-00033.jpg'], 
 ['C:\\Users\\AIIMS-IITD\\Desktop\\Sanjeev\\4_class_cluster_volume\\Train\\00_5\\161885\\IMG-0029-00038.jpg'], 
 ['C:\\Users\\AIIMS-IITD\\Desktop\\Sanjeev\\4_class_cluster_volume\\Train\\00_5\\161885\\IMG-0029-00047.jpg'],
 ['C:\\Users\\AIIMS-IITD\\Desktop\\Sanjeev\\4_class_cluster_volume\\Train\\00_5\\161885\\IMG-0029-00057.jpg'],
 ['C:\\Users\\AIIMS-IITD\\Desktop\\Sanjeev\\4_class_cluster_volume\\Train\\00_5\\161885\\IMG-0029-00063.jpg'],
 ['C:\\Users\\AIIMS-IITD\\Desktop\\Sanjeev\\4_class_cluster_volume\\Train\\00_5\\161885\\IMG-0029-00072.jpg'],
 ['C:\\Users\\AIIMS-IITD\\Desktop\\Sanjeev\\4_class_cluster_volume\\Train\\00_5\\161885\\IMG-0029-00079.jpg'], 
 ['C:\\Users\\AIIMS-IITD\\Desktop\\Sanjeev\\4_class_cluster_volume\\Train\\00_5\\161885\\IMG-0029-00082.jpg'],
 ['C:\\Users\\AIIMS-IITD\\Desktop\\Sanjeev\\4_class_cluster_volume\\Train\\00_5\\161885\\IMG-0029-00089.jpg'],
 ['C:\\Users\\AIIMS-IITD\\Desktop\\Sanjeev\\4_class_cluster_volume\\Train\\00_5\\161885\\IMG-0029-00099.jpg'],
 ['C:\\Users\\AIIMS-IITD\\Desktop\\Sanjeev\\4_class_cluster_volume\\Train\\00_5\\161885\\IMG-0029-00106.jpg'],
 ['C:\\Users\\AIIMS-IITD\\Desktop\\Sanjeev\\4_class_cluster_volume\\Train\\00_5\\161885\\IMG-0029-00112.jpg'],
 ['C:\\Users\\AIIMS-IITD\\Desktop\\Sanjeev\\4_class_cluster_volume\\Train\\00_5\\161885\\IMG-0029-00119.jpg'],
 ['C:\\Users\\AIIMS-IITD\\Desktop\\Sanjeev\\4_class_cluster_volume\\Train\\00_5\\161885\\IMG-0029-00123.jpg'],
 ['C:\\Users\\AIIMS-IITD\\Desktop\\Sanjeev\\4_class_cluster_volume\\Train\\00_5\\161885\\IMG-0029-00135.jpg'],
 ['C:\\Users\\AIIMS-IITD\\Desktop\\Sanjeev\\4_class_cluster_volume\\Train\\00_5\\161885\\IMG-0029-00138.jpg'],
 ['C:\\Users\\AIIMS-IITD\\Desktop\\Sanjeev\\4_class_cluster_volume\\Train\\00_5\\161885\\IMG-0029-00144.jpg'],
 ['C:\\Users\\AIIMS-IITD\\Desktop\\Sanjeev\\4_class_cluster_volume\\Train\\00_5\\161885\\IMG-0029-00150.jpg'],
 ['C:\\Users\\AIIMS-IITD\\Desktop\\Sanjeev\\4_class_cluster_volume\\Train\\00_5\\161885\\IMG-0029-00157.jpg'],
 ['C:\\Users\\AIIMS-IITD\\Desktop\\Sanjeev\\4_class_cluster_volume\\Train\\00_5\\161885\\IMG-0029-00166.jpg'],
 ['C:\\Users\\AIIMS-IITD\\Desktop\\Sanjeev\\4_class_cluster_volume\\Train\\00_5\\161885\\IMG-0029-00176.jpg']]
